# %%
import pandas as pd
import matplotlib as plot
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Task 1

# %%
q1data= pd.read_csv("Data/Lab2/q1data.csv")
q1data
# Out:
#       income  life_exp  population  year      country four_regions  \
# 0     1910.0      61.0  29200000.0  2010  Afghanistan         asia
# 1    11100.0      78.1   2950000.0  2010      Albania       europe
# 2    11100.0      74.7  36000000.0  2010      Algeria       africa
# 3    46900.0      81.9     84500.0  2010      Andorra       europe
# 4     7680.0      60.8  23400000.0  2010       Angola       africa
# ..       ...       ...         ...   ...          ...          ...
# 192  20400.0      75.4  28400000.0  2010    Venezuela     americas
# 193   5350.0      73.3  88000000.0  2010      Vietnam         asia
# 194   4700.0      67.8  23200000.0  2010        Yemen         asia
# 195   3200.0      57.5  13600000.0  2010       Zambia       africa
# 196   2560.0      54.4  12700000.0  2010     Zimbabwe       africa
#
#                   six_regions       eight_regions           world_bank_region
# 0                  south_asia           asia_west                  South Asia
# ...

# %%
pal_color = ["red", "orange", "cyan", "lime"]

# %%
plt.figure(figsize=(12, 6))
plot1 = sns.scatterplot(data=q1data, x="income", y="life_exp", size="population", hue = "four_regions", 
                        palette = pal_color, alpha=0.7, linewidth = 1, sizes=(50, 1500))
plot1.set(xlabel = "Income", ylabel="Life Expectancy", xscale= "log", ylim=(10,90))
plot1.set_xticks([400, 500, 1000, 2000, 4000, 8000, 16000, 32000, 64000])
plot1.set_xticklabels(["0", "500", "1000", "2000", "4000", "8000", "16k", "32k", "64k"])
plt.grid(alpha=0.2) 
plt.text(0.15, 0.28, '2010', fontsize = 180, alpha=0.1, transform=plot1.transAxes)

plt.legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# The Variables used for Task 1 were:
# - Income for the X-axis
# - Life Expectancy (life_exp) for the Y-axis
# - Population for the size of the bubbles
# - Four Regions for the colors of the bubbles

# %% [markdown]
# ### Task 2

# %%
q2data= pd.read_csv("Data/Lab2/q2data.csv")
q2data
# Out:
#      imports  exports energy  year                country four_regions  \
# 0        NaN      NaN    NaN  1997            Afghanistan         asia
# 1       36.7     11.5    427  1997                Albania       europe
# 2       22.5     22.6    825  1997                Algeria       africa
# 3        NaN      NaN    NaN  1997         American Samoa          NaN
# 4        NaN      NaN    434  1997                 Angola       africa
# ..       ...      ...    ...   ...                    ...          ...
# 201     52.2     44.8    340  1997                Vietnam         asia
# 202      NaN      NaN    NaN  1997  Virgin Islands (U.S.)          NaN
# 203      NaN      NaN    241  1997                  Yemen          NaN
# 204     31.6     24.6    617  1997                 Zambia       africa
# 205     45.1     43.4    845  1997               Zimbabwe       africa
#
#                   six_regions       eight_regions           world_bank_region
# ...

# %%
plt.figure(figsize=(12, 6))
plot2 = sns.scatterplot(data=q2data, x="exports", y="imports", size="energy", hue = "four_regions", 
                        palette = pal_color, alpha=0.7, linewidth = 1, sizes=(20, 800), legend = False)
plot2.set(xlabel = "Exports (\% of GDP)", ylabel="Imports (\% of GDP)", xlim = (0,220), ylim=(-20,400))
plot2.set_xticks([20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240])
plt.text(0.08, 0.25, '1997', fontsize = 180, alpha=0.1, transform=plot2.transAxes)

plt.grid(alpha=0.2)

# %% [markdown]
# The Variables used for Task 2 were:
# - Exports for the X-axis
# - Imports for the Y-axis
# - Energy use for the size of the bubbles
# - Four Regions for the colors of the bubbles

# %% [markdown]
# ### Task 3

# %%
q3data= pd.read_csv("Data/Lab2/q3data.csv")
q3data
# Out:
#      internet_users      gdp   income  year                country  \
# 0           0.00456    330.0   1190.0  2001            Afghanistan
# 1           0.39000   2570.0   6780.0  2001                Albania
# 2           1.59000   3770.0   9230.0  2001                Algeria
# 3               NaN  10500.0      NaN  2001         American Samoa
# 4          11.30000  42600.0  35600.0  2001                Andorra
# ..              ...      ...      ...   ...                    ...
# 210         1.85000    847.0   3270.0  2001                Vietnam
# 211        27.50000  36700.0      NaN  2001  Virgin Islands (U.S.)
# 212         0.51900   1190.0   4940.0  2001                  Yemen
# 213         0.47800    991.0   2080.0  2001                 Zambia
# 214         1.10000   1330.0   3190.0  2001               Zimbabwe
#
#     four_regions               six_regions       eight_regions  \
# 0           asia                south_asia           asia_west
# ...

# %%
plt.figure(figsize=(12, 6))
plot3 = sns.scatterplot(data=q3data, x="internet_users", y="gdp", size="income", hue = "four_regions", 
                        palette = pal_color, alpha=0.7, linewidth = 1, sizes=(20, 800), legend = False)
plot3.set(xlabel = "Individuals using the Internet", ylabel="GDP/capita", yscale= "log", xlim = (-2,90))
plot3.set_yticks([200, 500, 1000, 2000, 5000, 10000, 20000, 50000, 100000])
plot3.set_yticklabels(["200", "500", "1000", "2000", "5000", "10k", "20k", "50k", "100k"])
plot3.set_xticks([10, 20, 30, 40, 50, 60, 70, 80, 90])
plt.text(0.1, 0.2, '2001', fontsize = 180, alpha=0.1, transform=plot3.transAxes)

plt.grid(alpha=0.2)

# %% [markdown]
# The Variables used for Task 3 were:
# - Individuals using the Internet (internet_users) for the X-axis
# - GDP for the Y-axis
# - Income use for the size of the bubbles
# - Four Regions for the colors of the bubbles

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# ##### Download and import the original data files from GapMinder and merge and wrangle them yourself to accomplish the graphs above.

# %% [markdown]
# ### Task 1

# %%
four_regions = pd.read_csv("Data/Lab2/Data Geographies - v1 - by Gapminder - list-of-countries-etc.csv")
income = pd.read_csv("Data/Lab2/income_per_person_gdppercapita_ppp_inflation_adjusted.csv")
life_expect = pd.read_csv("Data/Lab2/life_expectancy_years.csv")
pop = pd.read_csv("Data/Lab2/population_total.csv")

# %%
income_2010 = income[["country", "2010"]]
income_2010 = income_2010.rename(columns = {"country":"country", "2010": "in_10"})

life_expect_2010 = life_expect[["country", "2010"]]
life_expect_2010 = life_expect_2010.rename(columns = {"country":"country", "2010": "life_ext_10"})

pop_2010 = pop[["country", "2010"]]
pop_2010 = pop_2010.rename(columns = {"country":"country", "2010": "pop_10"})

four_regions = four_regions[["name", "four_regions"]]
four_regions = four_regions.rename(columns = {"name":"country", "four_regions": "four_regions"})
four_regions
# Out:
#          country four_regions
# 0    Afghanistan         asia
# 1        Albania       europe
# 2        Algeria       africa
# 3        Andorra       europe
# 4         Angola       africa
# ..           ...          ...
# 192      Vietnam         asia
# 193        Yemen         asia
# 194       Zambia       africa
# 195     Zimbabwe       africa
# 196  South Sudan       africa
#
# [197 rows x 2 columns]

# %%
pop_2010.pop_10 = pop_2010['pop_10'].replace({'k': '*1e3', 'M': '*1e6', 'B': '1e9'}, regex=True).map(pd.eval).astype(int)
income_2010.in_10 = income_2010['in_10'].replace({'k': '*1e3', 'M': '*1e6', 'B': '1e9'}, regex=True).map(pd.eval).astype(int)

# %%
ex1data = four_regions.merge(income_2010, on = 'country')
ex1data = ex1data.merge(life_expect_2010, on = 'country')
ex1data = ex1data.merge(pop_2010, on = 'country')
ex1data
# Out:
#          country four_regions  in_10  life_ext_10    pop_10
# 0    Afghanistan         asia   1910         61.0  30100000
# 1        Albania       europe  11100         78.1   2930000
# 2        Algeria       africa  11100         74.7  36700000
# 3        Andorra       europe  46900         81.9     83700
# 4         Angola       africa   7680         60.8  24200000
# ..           ...          ...    ...          ...       ...
# 188      Vietnam         asia   5350         73.3  88900000
# 189        Yemen         asia   4700         67.8  23800000
# 190       Zambia       africa   3200         57.5  14000000
# 191     Zimbabwe       africa   2560         54.4  12900000
# 192  South Sudan       africa   4140         60.5   9830000
#
# [193 rows x 5 columns]

# %%
plt.figure(figsize=(12, 6))
plot1 = sns.scatterplot(data=ex1data, x="in_10", y="life_ext_10", size="pop_10", hue = "four_regions", 
                        palette = pal_color, alpha=0.7, linewidth = 1, sizes=(50, 1500))
plot1.set(xlabel = "Income", ylabel="Life Expectancy", xscale= "log", ylim=(10,90))
plot1.set_xticks([400, 500, 1000, 2000, 4000, 8000, 16000, 32000, 64000])
plot1.set_xticklabels(["0", "500", "1000", "2000", "4000", "8000", "16k", "32k", "64k"])
plt.grid(alpha=0.2) 
plt.text(0.15, 0.28, '2010', fontsize = 180, alpha=0.1, transform=plot1.transAxes)

plt.legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# ### Task 2

# %%
exports = pd.read_csv("Data/Lab2/exports_percent_of_gdp.csv")
imports = pd.read_csv("Data/Lab2/imports_percent_of_gdp.csv")
energy = pd.read_csv("Data/Lab2/energy_use_per_person.csv")

# %%
exports_1997 = exports[["country", "1997"]]
exports_1997 = exports_1997.rename(columns = {"country":"country", "1997": "export_97"})

imports_1997 = imports[["country", "1997"]]
imports_1997 = imports_1997.rename(columns = {"country":"country", "1997": "import_97"})

energy_1997 = energy[["country", "1997"]]
energy_1997 = energy_1997.rename(columns = {"country":"country", "1997": "energy_97"})

# %%
energy_1997.fillna('0', inplace=True)
energy_1997
# Out:
#                   country energy_97
# 0                  Angola       434
# 1                 Albania       427
# 2    United Arab Emirates     11.2k
# 3               Argentina      1660
# 4                 Armenia       610
# ..                    ...       ...
# 168                 Samoa         0
# 169                 Yemen       241
# 170          South Africa      2470
# 171                Zambia       617
# 172              Zimbabwe       845
#
# [173 rows x 2 columns]

# %%
energy_1997.energy_97 = energy_1997['energy_97'].replace({'k': '*1e3', 'M': '*1e6', 'B': '1e9'}, regex=True).map(pd.eval).astype(int)

# %%
ex2data = four_regions.merge(exports_1997, on = 'country')
ex2data = ex2data.merge(imports_1997, on = 'country')
ex2data = ex2data.merge(energy_1997, on = 'country')
ex2data
# Out:
#                  country four_regions  export_97  import_97  energy_97
# 0                Albania       europe       11.5       36.7        427
# 1                Algeria       africa       22.6       22.5        825
# 2                 Angola       africa        NaN        NaN        434
# 3    Antigua and Barbuda     americas      112.0       83.4          0
# 4              Argentina     americas       10.4       12.9       1660
# ..                   ...          ...        ...        ...        ...
# 157            Venezuela     americas       20.9       22.7       2250
# 158              Vietnam         asia       44.8       52.2        340
# 159               Zambia       africa       24.6       31.6        617
# 160             Zimbabwe       africa       43.4       45.1        845
# 161          South Sudan       africa        NaN        NaN          0
#
# [162 rows x 5 columns]

# %%
plt.figure(figsize=(12, 6))
plot2 = sns.scatterplot(data=ex2data, x="export_97", y="import_97", size="energy_97", hue = "four_regions", 
                        palette = pal_color, alpha=0.7, linewidth = 1, sizes=(20, 800), legend = False)
plot2.set(xlabel = "Exports (\% of GDP)", ylabel="Imports (\% of GDP)", xlim = (0,220), ylim=(-20,400))
plot2.set_xticks([20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240])
plt.text(0.08, 0.25, '1997', fontsize = 180, alpha=0.1, transform=plot2.transAxes)

plt.grid(alpha=0.2)

# %% [markdown]
# ### Task 3

# %%
gdp = pd.read_csv("Data/Lab2/gdppercapita_us_inflation_adjusted.csv")
internet = pd.read_csv("Data/Lab2/it_net_user_zs.csv")

# %%
gdp_2001 = gdp[["country", "2001"]]
gdp_2001 = gdp_2001.rename(columns = {"country":"country", "2001": "gdp_01"})

internet_2001 = internet[["country", "2001"]]
internet_2001 = internet_2001.rename(columns = {"country":"country", "2001": "internet_01"})

income_2001 = income[["country", "2001"]]
income_2001 = income_2001.rename(columns = {"country":"country", "2001": "in_01"})

# %%
gdp_2001.fillna('0', inplace=True)
gdp_2001.gdp_01 = gdp_2001['gdp_01'].replace({'k': '*1e3', 'M': '*1e6', 'B': '1e9'}, regex=True).map(pd.eval).astype(int)

income_2001.in_01 = income_2001['in_01'].replace({'k': '*1e3', 'M': '*1e6', 'B': '1e9'}, regex=True).map(pd.eval).astype(int)

# %%
ex3data = four_regions.merge(gdp_2001, on = 'country')
ex3data = ex3data.merge(internet_2001, on = 'country')
ex3data = ex3data.merge(income_2001, on = 'country')
ex3data
# Out:
#          country four_regions  gdp_01  internet_01  in_01
# 0    Afghanistan         asia     333      0.00456   1190
# 1        Albania       europe    2250      0.39000   6780
# 2        Algeria       africa    3300      1.59000   9230
# 3        Andorra       europe   36200     11.30000  35600
# 4         Angola       africa    2720      0.27000   2900
# ..           ...          ...     ...          ...    ...
# 183      Vietnam         asia    1060      1.85000   3270
# 184        Yemen         asia    2430      0.51900   4940
# 185       Zambia       africa     808      0.47800   2080
# 186     Zimbabwe       africa    1560      1.10000   3190
# 187  South Sudan       africa       0          NaN   3330
#
# [188 rows x 5 columns]

# %%
plt.figure(figsize=(12, 6))
plot3 = sns.scatterplot(data=ex3data, x="internet_01", y="gdp_01", size="in_01", hue = "four_regions", 
                        palette = pal_color, alpha=0.7, linewidth = 1, sizes=(20, 800), legend = False)
plot3.set(xlabel = "Individuals using the Internet", ylabel="GDP/capita", yscale= "log", xlim = (-2,90), ylim=(100, 175000))
plot3.set_yticks([200, 500, 1000, 2000, 5000, 10000, 20000, 50000, 100000])
plot3.set_yticklabels(["200", "500", "1000", "2000", "5000", "10k", "20k", "50k", "100k"])
plot3.set_xticks([10, 20, 30, 40, 50, 60, 70, 80, 90])
plt.text(0.1, 0.2, '2001', fontsize = 180, alpha=0.1, transform=plot1.transAxes)

plt.grid(alpha=0.2)
